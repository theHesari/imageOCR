# %%
# !pip install pytesseract

# %% [markdown]
# #import libraries

# %%
import cv2
import pytesseract
from google.colab.patches import cv2_imshow

# %% [markdown]
# #Read the Image

# %%
img = cv2.imread('/images/image01.jpeg')

# %% [markdown]
# #Output

# %%
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2_imshow(img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1249x1874>
# -1
